# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
from pipeline import portfolio, run
import pandas as pd

tickers = pd.read_csv('results/universe_selection/final_assets.csv', skiprows = 1, header = None)[0].tolist()

results = portfolio.aggregate_results(tickers)
portfolio_df = portfolio.build_portfolio(tickers, results)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       6 results = portfolio.aggregate_results(tickers)
#       7 portfolio_df = portfolio.build_portfolio(tickers, results)
# ----> 8 run.analyze_portfolio(portfolio_df)
#
# File ~/Documents/GitHub/entropy-trading/pipeline/run.py:96, in analyze_portfolio(df)
#      95 def analyze_portfolio(df):
# ---> 96     generate_portfolio()
#      97     calculate_portfolio(df)
#
# TypeError: generate_portfolio() missing 2 required positional arguments: 'df' and 'ticker'

# %%
run.analyze_portfolio(portfolio_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
