# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
import os
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/Users/ak/Documents/GitHub/entropy-trading'

# %%
from pipeline import grid_search
import pandas as pd

tickers = pd.read_csv('results/universe_selection/final_assets.csv', skiprows = 1, header = None)[0].tolist()

results = grid_search.iterate_pairs(tickers)
results.to_csv('results/grid_search_results.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 6
#       2 import pandas as pd
#       4 tickers = pd.read_csv('results/universe_selection/final_assets.csv', skiprows = 1, header = None)[0].tolist()
# ----> 6 results = grid_search.iterate_pairs(tickers)
#       7 results.to_csv('results/grid_search_results.csv')
#
# File ~/Documents/GitHub/entropy-trading/pipeline/grid_search.py:28, in iterate_pairs(tickers, gammas, modes, windows)
#      25 results = pd.DataFrame()
#      27 for gamma, mode, window in product(gammas, modes, windows):
# ---> 28     portfolio = set_parameters(tickers, gamma, mode, window)
#      29     sharpe = portfolio.calculate_sharpe(portfolio['Blend Return'])
# ...
