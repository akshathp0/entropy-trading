# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/Users/ak/Documents/GitHub/entropy-trading'

# %%
import pandas as pd
from pipeline import grid_search

results = pd.read_csv('results/grid_search_results.csv')

gamma, mode, window = grid_search.find_parameters(results)
print(f'optimal gamma: {gamma}')
print(f'optimal mode: {mode}')
print(f'optimal window: {window}')
# Out:
# optimal gamma: 2.0
# optimal mode: portfolio_only
# optimal window: 750
