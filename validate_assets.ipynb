# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
from pipeline import run
import pandas as pd

tickers = pd.read_csv('results/universe_selection/final_assets.csv', skiprows = 1, header = None)[0].tolist()

for ticker in tickers:
    df = run.run_pipeline(ticker)
    run.analyze_ticker(df, ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 252
# [*********************100%***********************]  1 of 1 completed
# VTV Mean-reversion-only Sharpe: 0.6503400086926467
# VTV Mean-reversion-only max drawdown: -0.1905334593642819
# VTV Mean-reversion-only annualized return: 0.06928210050004258
# VTV Momentum-only Sharpe: 0.4194168407931523
# VTV Momentum-only max drawdown: -0.29428171728778024
# VTV Momentum-only annualized return: 0.04094152119529948
# [*********************100%***********************]  1 of 1 completed
# 252
# [*********************100%***********************]  1 of 1 completed
# XLU Mean-reversion-only Sharpe: 0.5796280277727927
# XLU Mean-reversion-only max drawdown: -0.24024724927821975
# XLU Mean-reversion-only annualized return: 0.06022426424423588
# XLU Momentum-only Sharpe: 0.26593779881063867
# XLU Momentum-only max drawdown: -0.4093772085890522
# XLU Momentum-only annualized return: 0.02629488482669662
# [*********************100%***********************]  1 of 1 completed
# 252
# [*********************100%***********************]  1 of 1 completed
# XLV Mean-reversion-only Sharpe: 0.7326871231614194
# XLV Mean-reversion-only max drawdown: -0.18351238740917228
# XLV Mean-reversion-only annualized return: 0.07079792089953019
# XLV Momentum-only Sharpe: 0.5476468600736578
# XLV Momentum-only max drawdown: -0.2378009967301713
# XLV Momentum-only annualized return: 0.06393810605720152
# [*********************100%***********************]  1 of 1 completed
# 252
# [*********************100%***********************]  1 of 1 completed
# EWJ Mean-reversion-only Sharpe: 0.8534120508780376
# EWJ Mean-reversion-only max drawdown: -0.2040420421029009
# EWJ Mean-reversion-only annualized return: 0.10814578174263878
# EWJ Momentum-only Sharpe: 0.14978974405471288
# EWJ Momentum-only max drawdown: -0.29669678253298887
# EWJ Momentum-only annualized return: 0.0107242593593877
# [*********************100%***********************]  1 of 1 completed
# 252
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# IBB Mean-reversion-only Sharpe: 0.5069941474909586
# IBB Mean-reversion-only max drawdown: -0.24530605441579642
# IBB Mean-reversion-only annualized return: 0.062202925405014264
# IBB Momentum-only Sharpe: 0.4167840384659407
# IBB Momentum-only max drawdown: -0.4059389021985133
# IBB Momentum-only annualized return: 0.05967469214207277
# 252
# [*********************100%***********************]  1 of 1 completed
# SPY Mean-reversion-only Sharpe: 0.7752730319903055
# SPY Mean-reversion-only max drawdown: -0.1826330907175759
# SPY Mean-reversion-only annualized return: 0.0841115661778935
# SPY Momentum-only Sharpe: 0.6823953309102323
# SPY Momentum-only max drawdown: -0.24219920807472037
# SPY Momentum-only annualized return: 0.08108449138746376
# [*********************100%***********************]  1 of 1 completed
# 252
# [*********************100%***********************]  1 of 1 completed
# /Users/ak/Documents/GitHub/entropy-trading/evaluation/plot.py:56: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize = (10, 5))
# GLD Mean-reversion-only Sharpe: 0.31244887712337505
# GLD Mean-reversion-only max drawdown: -0.25927980989855043
# GLD Mean-reversion-only annualized return: 0.025606013407634798
# GLD Momentum-only Sharpe: 0.3721354193670472
# GLD Momentum-only max drawdown: -0.3920141464012807
# GLD Momentum-only annualized return: 0.03689161506072458
