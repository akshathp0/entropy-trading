# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pipeline import run
import pandas as pd
from backtests import mean_reversion
from backtests import momentum_backtest
from evaluation import metrics, plot

tickers = pd.read_csv('results/universe_selection/final_assets.csv', skiprows = 1, header = None)[0].tolist()

for ticker in tickers:
    df = run.run_pipeline(ticker)
    run.analyze_ticker(df, ticker)

    df = mean_reversion.mr_backtest(df)

    print(f"{ticker} Mean-reversion-only Sharpe: {metrics.calculate_sharpe(df['MR Return'])}")
    print(f"{ticker} Mean-reversion-only max drawdown: {metrics.calculate_max_drawdown(df['MR Return'])}")
    print(f"{ticker} Mean-reversion-only annualized return: {metrics.calculate_annualized_returns(df['MR Return'])}")

    df = momentum_backtest.momentum_backtest(df)
    print(f"{ticker} Momentum-only Sharpe: {metrics.calculate_sharpe(df['Momentum Return'])}")
    print(f"{ticker} Momentum-only max drawdown: {metrics.calculate_max_drawdown(df['Momentum Return'])}")
    print(f"{ticker} Momentum-only annualized return: {metrics.calculate_annualized_returns(df['Momentum Return'])}")
# Out:
# [*********************100%***********************]  1 of 1 completed
# 60
